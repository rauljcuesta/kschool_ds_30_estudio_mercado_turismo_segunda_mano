# %%
import pandas as pd
import zipfile
import os
import tarfile
import math
import numpy as np

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)

# %%
data_route = './../data/dgt/';

# %%
def gbk_to_utf8(input_file, output_file):
    # Load Files
    input_file_opened = open(input_file, 'r', encoding='ISO-8859-1')
    input_file_read = input_file_opened.read()
    input_file_opened.close()
    os.remove(input_file)
    
    output_file_opened = open(output_file, 'x', encoding='utf-8', newline='\n')
    # Transcode
    print('---- Transcoding…')
    output_file_opened.write(input_file_read)
    output_file_opened.close()
    
    print('---- Transcoding Done')

# %%
def extract_dataframe_dgt_tourist(route_files, file_zip):
    
    widths = [8,1,8,30,22,1,21,2,1,5,6,6,6,3,2,2,2,2,24,2,2,1,8,5,8,1,1,9,3,5,30,7,3,5,1,1,1,1,1,1,11,25,25,35,70,6,6,4,4,3,8,4,4,4,6,30,50,35,25,35,4,4,4,1,25,1,4,25,8]
    columns = ['FEC_MATRICULA','COD_CLASE_MAT','FEC_TRAMITACION','MARCA_ITV','MODELO_ITV','COD_PROCEDENCIA_ITV','BASTIDOR_ITV','COD_TIPO','COD_PROPULSION_ITV','CILINDRADA_ITV','POTENCIA_ITV','TARA','PESO_MAX','NUM_PLAZAS','IND_PRECINTO','IND_EMBARGO','NUM_TRANSMISIONES','NUM_TITULARES','LOCALIDAD_VEHICULO','COD_PROVINCIA_VEH','COD_PROVINCIA_MAT','CLAVE_TRAMITE','FEC_TRAMITE','CODIGO_POSTAL','FEC_PRIM_MATRICULACION','IND_NUEVO_USADO','PERSONA_FISICA_JURIDICA','CODIGO_ITV','SERVICIO','COD_MUNICIPIO_INE_VEH','MUNICIPIO','KW_ITV','NUM_PLAZAS_MAX','CO2_ITV','RENTING','COD_TUTELA','COD_POSESION','IND_BAJA_DEF','IND_BAJA_TEMP','IND_SUSTRACCION','BAJA_TELEMATICA','TIPO_ITV','VARIANTE_ITV','VERSION_ITV','FABRICANTE_ITV','MASA_ORDEN_MARCHA_ITV','MASA_MÁXIMA_TECNICA_ADMISIBLE_ITV','CATEGORÍA_HOMOLOGACIÓN_EUROPEA_ITV','CARROCERIA','PLAZAS_PIE','NIVEL_EMISIONES_EURO_ITV','CONSUMO_WH/KM_ITV','CLASIFICACIÓN_REGLAMENTO_VEHICULOS_ITV','CATEGORÍA_VEHÍCULO_ELÉCTRICO','AUTONOMÍA_VEHÍCULO_ELÉCTRICO','MARCA_VEHÍCULO_BASE','FABRICANTE_VEHÍCULO_BASE','TIPO_VEHÍCULO_BASE','VARIANTE_VEHÍCULO_BASE','VERSIÓN_VEHÍCULO_BASE','DISTANCIA_EJES_12','VIA_ANTERIOR_ITV','VIA_POSTERIOR_ITV','TIPO_ALIMENTACION_ITV','CONTRASEÑA_HOMOLOGACION_ITV','ECO_INNOVACION_ITV','REDUCCION_ECO_ITV','CODIGO_ECO_ITV','FEC_PROCESO']
    tourist_code = '40'

    print('-- Decompress file…')

    with zipfile.ZipFile(route_files+file_zip,"r") as zip_ref:
        zip_ref.extractall(path=route_files, members=None, pwd=None)
        
    file_txt = zip_ref.namelist()[0]
    
    print('-- Change encode to UTF-8')
    gbk_to_utf8(route_files+file_txt, route_files+file_txt)
    
    print('-- Transform to dataframe…')
    dgt_df = pd.read_fwf(route_files+file_txt, widths = widths, header=None)
    dgt_df.columns = columns
    
    os.remove(route_files+file_txt)
    
    dgt_df.replace('^\s+', '', regex=True, inplace=True) #front
    dgt_df.replace('\s+$', '', regex=True, inplace=True) #end
    
    print('-- Extract tourist rows')
    dgt_df = dgt_df[dgt_df['COD_TIPO'] == tourist_code].reset_index()
    
    return dgt_df

# %%
def make_tarfile(csv_file, data_route):
    with tarfile.open(csv_file+'tar.gz', "w:gz") as tar:
        tar.add(data_route+csv_file, arcname=os.path.basename(data_route))
        tar.close()

# %%
def create_csv_tar_gz(year):

    dgt_df = create_dataset_tourist_year(year)
    
    csv_file = "export_anual_trf_"+year+".csv"

    dgt_df.to_csv(data_route+csv_file, index=False, sep="^")
    

    #make_tarfile(csv_file,data_route)

# %%
def reduce_fields(data_set):    
    return data_set[['FEC_MATRICULA','COD_CLASE_MAT','FEC_TRAMITACION','MARCA_ITV','MODELO_ITV','COD_PROCEDENCIA_ITV','COD_PROPULSION_ITV','CILINDRADA_ITV','POTENCIA_ITV','NUM_PLAZAS','NUM_TRANSMISIONES','NUM_TITULARES','LOCALIDAD_VEHICULO','COD_PROVINCIA_VEH','COD_PROVINCIA_MAT','CLAVE_TRAMITE','FEC_TRAMITE','CODIGO_POSTAL','FEC_PRIM_MATRICULACION','IND_NUEVO_USADO','PERSONA_FISICA_JURIDICA','COD_MUNICIPIO_INE_VEH','MUNICIPIO','KW_ITV','NUM_PLAZAS_MAX','CO2_ITV','RENTING','CATEGORÍA_HOMOLOGACIÓN_EUROPEA_ITV','NIVEL_EMISIONES_EURO_ITV','CONSUMO_WH/KM_ITV','CATEGORÍA_VEHÍCULO_ELÉCTRICO','AUTONOMÍA_VEHÍCULO_ELÉCTRICO']]

# %%
def month_to_quarter(month):
    if (month >= 1 and month <=12):
        return (month-1)//3 + 1
    else:
        return np.nan

# %%
def create_new_fields(df):
    
    print('-- START format dates and create new fields')
    df['FEC_MATRICULA'] = df['FEC_MATRICULA'].apply(lambda x: pd.to_datetime(str(x)[-4:]+'-'+str(x)[-6:-4]+'-'+str(x)[:-6]) )
    df['FEC_TRAMITACION'] = df['FEC_TRAMITACION'].apply(lambda x: (pd.to_datetime(str(int(x))[-4:]+'-'+str(int(x))[-6:-4]+'-'+str(int(x))[:-6])) if not math.isnan(x) else x )
    df['FEC_TRAMITE'] = df['FEC_TRAMITE'].apply(lambda x: pd.to_datetime(str(x)[-4:]+'-'+str(x)[-6:-4]+'-'+str(x)[:-6]) )
    # df['FEC_PROCESO'] = df['FEC_PROCESO'].apply(lambda x: pd.to_datetime(str(x)[-4:]+'-'+str(x)[-6:-4]+'-'+str(x)[:-6]) )
    df['year_Q'] = df['FEC_TRAMITE'].apply(lambda x: x.strftime("%Y") )
    df['Q_query'] = df['FEC_TRAMITE'].apply(lambda x: month_to_quarter(int(x.strftime("%m"))) )
    df['FEC_PRIM_MATRICULACION'] = df['FEC_PRIM_MATRICULACION'].apply(lambda x: (pd.to_datetime(str(int(x))[-4:]+'-'+str(int(x))[-6:-4]+'-'+str(int(x))[:-6])) if not math.isnan(x) else x )
    print('-- END format dates and create new fields')
    
    return df

# %%
def create_dataset_tourist_year(year):

    dgt_df = False

    for subdir, dirs, files in os.walk(data_route):
        for file in sorted(files):
            if ( file.find('.zip') != -1 and file.find(year) != -1):
                print(file)

                df_aux = extract_dataframe_dgt_tourist(data_route, file)
                df_aux = reduce_fields(df_aux)
                df_aux = create_new_fields(df_aux)

                if (type(dgt_df) == pd.core.frame.DataFrame):
                    dgt_df = pd.concat([dgt_df,df_aux], keys=None)
                else:
                    dgt_df = df_aux.copy()
                    
    return dgt_df

# %%
for year in ['2015', '2016', '2017','2018','2019','2020','2021','2022']:
    print(year)
    create_csv_tar_gz(year)
# Out:
# 2015
# export_mensual_trf_201501.zip
# -- Decompress file…
# -- Change encode to UTF-8
# ---- Transcoding…
# ---- Transcoding Done
# -- Transform to dataframe…
# -- Extract tourist rows
# -- START format dates and create new fields
# -- END format dates and create new fields
# export_mensual_trf_201502.zip
# -- Decompress file…
# -- Change encode to UTF-8
# ---- Transcoding…
# ---- Transcoding Done
# -- Transform to dataframe…
# -- Extract tourist rows
# -- START format dates and create new fields
# -- END format dates and create new fields
# export_mensual_trf_201503.zip
# -- Decompress file…
# -- Change encode to UTF-8
# ---- Transcoding…
# ---- Transcoding Done
# -- Transform to dataframe…
# -- Extract tourist rows
# -- START format dates and create new fields
# -- END format dates and create new fields
# export_mensual_trf_201504.zip
# -- Decompress file…
# -- Change encode to UTF-8
# ---- Transcoding…
# ---- Transcoding Done
# -- Transform to dataframe…
# -- Extract tourist rows
# -- START format dates and create new fields
# -- END format dates and create new fields
# export_mensual_trf_201505.zip
# -- Decompress file…
# -- Change encode to UTF-8
# ---- Transcoding…
# ---- Transcoding Done
# -- Transform to dataframe…
# -- Extract tourist rows
# -- START format dates and create new fields
# -- END format dates and create new fields
# export_mensual_trf_201506.zip
# -- Decompress file…
# -- Change encode to UTF-8
# ---- Transcoding…
# ---- Transcoding Done
# -- Transform to dataframe…
# -- Extract tourist rows
# -- START format dates and create new fields
# -- END format dates and create new fields
# export_mensual_trf_201507.zip
# -- Decompress file…
# -- Change encode to UTF-8
# ---- Transcoding…
# ---- Transcoding Done
# -- Transform to dataframe…
# -- Extract tourist rows
# -- START format dates and create new fields
# -- END format dates and create new fields
# export_mensual_trf_201508.zip
# -- Decompress file…
# -- Change encode to UTF-8
# ---- Transcoding…
# ---- Transcoding Done
# -- Transform to dataframe…
# -- Extract tourist rows
# -- START format dates and create new fields
# -- END format dates and create new fields
# export_mensual_trf_201509.zip
# -- Decompress file…
# -- Change encode to UTF-8
# ---- Transcoding…
# ---- Transcoding Done
# -- Transform to dataframe…
# -- Extract tourist rows
# -- START format dates and create new fields
# -- END format dates and create new fields
# export_mensual_trf_201510.zip
# -- Decompress file…
# -- Change encode to UTF-8
# ---- Transcoding…
# ---- Transcoding Done
# -- Transform to dataframe…
# -- Extract tourist rows
# -- START format dates and create new fields
# -- END format dates and create new fields
# export_mensual_trf_201511.zip
# -- Decompress file…
# -- Change encode to UTF-8
# ---- Transcoding…
# ---- Transcoding Done
# -- Transform to dataframe…
# -- Extract tourist rows
# -- START format dates and create new fields
# -- END format dates and create new fields
# export_mensual_trf_201512.zip
# -- Decompress file…
# -- Change encode to UTF-8
# ---- Transcoding…
# ---- Transcoding Done
# -- Transform to dataframe…
# -- Extract tourist rows
# -- START format dates and create new fields
# -- END format dates and create new fields
# 2016
# export_mensual_trf_201601.zip
# -- Decompress file…
# -- Change encode to UTF-8
# ---- Transcoding…
# ---- Transcoding Done
# -- Transform to dataframe…
# -- Extract tourist rows
# -- START format dates and create new fields
# -- END format dates and create new fields
# export_mensual_trf_201602.zip
# -- Decompress file…
# -- Change encode to UTF-8
# ---- Transcoding…
# ---- Transcoding Done
# -- Transform to dataframe…
# -- Extract tourist rows
# -- START format dates and create new fields
# -- END format dates and create new fields
# export_mensual_trf_201603.zip
# -- Decompress file…
# -- Change encode to UTF-8
# ---- Transcoding…
# ---- Transcoding Done
# -- Transform to dataframe…
# -- Extract tourist rows
# -- START format dates and create new fields
# -- END format dates and create new fields
# export_mensual_trf_201604.zip
# -- Decompress file…
# -- Change encode to UTF-8
# ---- Transcoding…
# ---- Transcoding Done
# -- Transform to dataframe…
# -- Extract tourist rows
# -- START format dates and create new fields
# -- END format dates and create new fields
# export_mensual_trf_201605.zip
# -- Decompress file…
# -- Change encode to UTF-8
# ---- Transcoding…
# ---- Transcoding Done
# -- Transform to dataframe…
# -- Extract tourist rows
# -- START format dates and create new fields
# -- END format dates and create new fields
# export_mensual_trf_201606.zip
# -- Decompress file…
# -- Change encode to UTF-8
# ---- Transcoding…
# ---- Transcoding Done
# -- Transform to dataframe…
# -- Extract tourist rows
# -- START format dates and create new fields
# -- END format dates and create new fields
# export_mensual_trf_201607.zip
# -- Decompress file…
# -- Change encode to UTF-8
# ---- Transcoding…
# ---- Transcoding Done
# -- Transform to dataframe…
# -- Extract tourist rows
# -- START format dates and create new fields
# -- END format dates and create new fields
# export_mensual_trf_201608.zip
# -- Decompress file…
# -- Change encode to UTF-8
# ---- Transcoding…
# ---- Transcoding Done
# -- Transform to dataframe…
# -- Extract tourist rows
# -- START format dates and create new fields
# -- END format dates and create new fields
# export_mensual_trf_201609.zip
# -- Decompress file…
# -- Change encode to UTF-8
# ---- Transcoding…
# ---- Transcoding Done
# -- Transform to dataframe…
# -- Extract tourist rows
# -- START format dates and create new fields
# -- END format dates and create new fields
# export_mensual_trf_201610.zip
# -- Decompress file…
# -- Change encode to UTF-8
# ---- Transcoding…
# ---- Transcoding Done
# -- Transform to dataframe…
# -- Extract tourist rows
# -- START format dates and create new fields
# -- END format dates and create new fields
# export_mensual_trf_201611.zip
# -- Decompress file…
# -- Change encode to UTF-8
# ---- Transcoding…
# ---- Transcoding Done
# -- Transform to dataframe…
# -- Extract tourist rows
# -- START format dates and create new fields
# -- END format dates and create new fields
# export_mensual_trf_201612.zip
# -- Decompress file…
# -- Change encode to UTF-8
# ---- Transcoding…
# ---- Transcoding Done
# -- Transform to dataframe…
# -- Extract tourist rows
# -- START format dates and create new fields
# -- END format dates and create new fields
# 2017
# export_mensual_trf_201701.zip
# -- Decompress file…
# -- Change encode to UTF-8
# ---- Transcoding…
# ---- Transcoding Done
# -- Transform to dataframe…
# -- Extract tourist rows
# -- START format dates and create new fields
# -- END format dates and create new fields
# export_mensual_trf_201702.zip
# -- Decompress file…
# -- Change encode to UTF-8
# ---- Transcoding…
# ---- Transcoding Done
# -- Transform to dataframe…
# -- Extract tourist rows
# -- START format dates and create new fields
# -- END format dates and create new fields
# export_mensual_trf_201703.zip
# -- Decompress file…
# -- Change encode to UTF-8
# ---- Transcoding…
# ---- Transcoding Done
# -- Transform to dataframe…
# -- Extract tourist rows
# -- START format dates and create new fields
# -- END format dates and create new fields
# export_mensual_trf_201704.zip
# -- Decompress file…
# -- Change encode to UTF-8
# ---- Transcoding…
# ---- Transcoding Done
# -- Transform to dataframe…
# -- Extract tourist rows
# -- START format dates and create new fields
# -- END format dates and create new fields
# export_mensual_trf_201705.zip
# -- Decompress file…
# -- Change encode to UTF-8
# ---- Transcoding…
# ---- Transcoding Done
# -- Transform to dataframe…
# -- Extract tourist rows
# -- START format dates and create new fields
# -- END format dates and create new fields
# export_mensual_trf_201706.zip
# -- Decompress file…
# -- Change encode to UTF-8
# ---- Transcoding…
# ---- Transcoding Done
# -- Transform to dataframe…
# -- Extract tourist rows
# -- START format dates and create new fields
# -- END format dates and create new fields
# export_mensual_trf_201707.zip
# -- Decompress file…
# -- Change encode to UTF-8
# ---- Transcoding…
# ---- Transcoding Done
# -- Transform to dataframe…
# -- Extract tourist rows
# -- START format dates and create new fields
# -- END format dates and create new fields
# export_mensual_trf_201708.zip
# -- Decompress file…
# -- Change encode to UTF-8
# ---- Transcoding…
# ---- Transcoding Done
# -- Transform to dataframe…
# -- Extract tourist rows
# -- START format dates and create new fields
# -- END format dates and create new fields
# export_mensual_trf_201709.zip
# -- Decompress file…
# -- Change encode to UTF-8
# ---- Transcoding…
# ---- Transcoding Done
# -- Transform to dataframe…
# -- Extract tourist rows
# -- START format dates and create new fields
# -- END format dates and create new fields
# export_mensual_trf_201710.zip
# -- Decompress file…
# -- Change encode to UTF-8
# ---- Transcoding…
# ---- Transcoding Done
# -- Transform to dataframe…
# -- Extract tourist rows
# -- START format dates and create new fields
# -- END format dates and create new fields
# export_mensual_trf_201711.zip
# -- Decompress file…
# -- Change encode to UTF-8
# ---- Transcoding…
# ---- Transcoding Done
# -- Transform to dataframe…
# -- Extract tourist rows
# -- START format dates and create new fields
# -- END format dates and create new fields
# export_mensual_trf_201712.zip
# -- Decompress file…
# -- Change encode to UTF-8
# ---- Transcoding…
# ---- Transcoding Done
# -- Transform to dataframe…
# -- Extract tourist rows
# -- START format dates and create new fields
# -- END format dates and create new fields
# 2018
# export_mensual_trf_201801.zip
# -- Decompress file…
# -- Change encode to UTF-8
# ---- Transcoding…
# ---- Transcoding Done
# -- Transform to dataframe…
# -- Extract tourist rows
# -- START format dates and create new fields
# -- END format dates and create new fields
# export_mensual_trf_201802.zip
# -- Decompress file…
# -- Change encode to UTF-8
# ---- Transcoding…
# ---- Transcoding Done
# -- Transform to dataframe…
# -- Extract tourist rows
# -- START format dates and create new fields
# -- END format dates and create new fields
# export_mensual_trf_201803.zip
# -- Decompress file…
# -- Change encode to UTF-8
# ---- Transcoding…
# ---- Transcoding Done
# -- Transform to dataframe…
# -- Extract tourist rows
# -- START format dates and create new fields
# -- END format dates and create new fields
# export_mensual_trf_201804.zip
# -- Decompress file…
# -- Change encode to UTF-8
# ---- Transcoding…
# ---- Transcoding Done
# -- Transform to dataframe…
# -- Extract tourist rows
# -- START format dates and create new fields
# -- END format dates and create new fields
# export_mensual_trf_201805.zip
# -- Decompress file…
# -- Change encode to UTF-8
# ---- Transcoding…
# ---- Transcoding Done
# -- Transform to dataframe…
# -- Extract tourist rows
# -- START format dates and create new fields
# -- END format dates and create new fields
# export_mensual_trf_201806.zip
# -- Decompress file…
# -- Change encode to UTF-8
# ---- Transcoding…
# ---- Transcoding Done
# -- Transform to dataframe…
# -- Extract tourist rows
# -- START format dates and create new fields
# -- END format dates and create new fields
# export_mensual_trf_201807.zip
# -- Decompress file…
# -- Change encode to UTF-8
# ---- Transcoding…
# ---- Transcoding Done
# -- Transform to dataframe…
# -- Extract tourist rows
# -- START format dates and create new fields
# -- END format dates and create new fields
# export_mensual_trf_201808.zip
# -- Decompress file…
# -- Change encode to UTF-8
# ---- Transcoding…
# ---- Transcoding Done
# -- Transform to dataframe…
# -- Extract tourist rows
# -- START format dates and create new fields
# -- END format dates and create new fields
# export_mensual_trf_201809.zip
# -- Decompress file…
# -- Change encode to UTF-8
# ---- Transcoding…
# ---- Transcoding Done
# -- Transform to dataframe…
# -- Extract tourist rows
# -- START format dates and create new fields
# -- END format dates and create new fields
# export_mensual_trf_201810.zip
# -- Decompress file…
# -- Change encode to UTF-8
# ---- Transcoding…
# ---- Transcoding Done
# -- Transform to dataframe…
# -- Extract tourist rows
# -- START format dates and create new fields
# -- END format dates and create new fields
# export_mensual_trf_201811.zip
# -- Decompress file…
# -- Change encode to UTF-8
# ---- Transcoding…
# ---- Transcoding Done
# -- Transform to dataframe…
# -- Extract tourist rows
# -- START format dates and create new fields
# -- END format dates and create new fields
# export_mensual_trf_201812.zip
# -- Decompress file…
# -- Change encode to UTF-8
# ---- Transcoding…
# ---- Transcoding Done
# -- Transform to dataframe…
# -- Extract tourist rows
# -- START format dates and create new fields
# -- END format dates and create new fields
# 2019
# export_mensual_trf_201901.zip
# -- Decompress file…
# -- Change encode to UTF-8
# ---- Transcoding…
# ---- Transcoding Done
# -- Transform to dataframe…
# -- Extract tourist rows
# -- START format dates and create new fields
# -- END format dates and create new fields
# export_mensual_trf_201902.zip
# -- Decompress file…
# -- Change encode to UTF-8
# ---- Transcoding…
# ---- Transcoding Done
# -- Transform to dataframe…
# -- Extract tourist rows
# -- START format dates and create new fields
# -- END format dates and create new fields
# export_mensual_trf_201903.zip
# -- Decompress file…
# -- Change encode to UTF-8
# ---- Transcoding…
# ---- Transcoding Done
# -- Transform to dataframe…
# -- Extract tourist rows
# -- START format dates and create new fields
# -- END format dates and create new fields
# export_mensual_trf_201904.zip
# -- Decompress file…
# -- Change encode to UTF-8
# ---- Transcoding…
# ---- Transcoding Done
# -- Transform to dataframe…
# -- Extract tourist rows
# -- START format dates and create new fields
# -- END format dates and create new fields
# export_mensual_trf_201905.zip
# -- Decompress file…
# -- Change encode to UTF-8
# ---- Transcoding…
# ---- Transcoding Done
# -- Transform to dataframe…
# -- Extract tourist rows
# -- START format dates and create new fields
# -- END format dates and create new fields
# export_mensual_trf_201906.zip
# -- Decompress file…
# -- Change encode to UTF-8
# ---- Transcoding…
# ---- Transcoding Done
# -- Transform to dataframe…
# -- Extract tourist rows
# -- START format dates and create new fields
# -- END format dates and create new fields
# export_mensual_trf_201907.zip
# -- Decompress file…
# -- Change encode to UTF-8
# ---- Transcoding…
# ---- Transcoding Done
# -- Transform to dataframe…
# -- Extract tourist rows
# -- START format dates and create new fields
# -- END format dates and create new fields
# export_mensual_trf_201908.zip
# -- Decompress file…
# -- Change encode to UTF-8
# ---- Transcoding…
# ---- Transcoding Done
# -- Transform to dataframe…
# -- Extract tourist rows
# -- START format dates and create new fields
# -- END format dates and create new fields
# export_mensual_trf_201909.zip
# -- Decompress file…
# -- Change encode to UTF-8
# ---- Transcoding…
# ---- Transcoding Done
# -- Transform to dataframe…
# -- Extract tourist rows
# -- START format dates and create new fields
# -- END format dates and create new fields
# export_mensual_trf_201910.zip
# -- Decompress file…
# -- Change encode to UTF-8
# ---- Transcoding…
# ---- Transcoding Done
# -- Transform to dataframe…
# -- Extract tourist rows
# -- START format dates and create new fields
# -- END format dates and create new fields
# export_mensual_trf_201911.zip
# -- Decompress file…
# -- Change encode to UTF-8
# ---- Transcoding…
# ---- Transcoding Done
# -- Transform to dataframe…
# -- Extract tourist rows
# -- START format dates and create new fields
# -- END format dates and create new fields
# export_mensual_trf_201912.zip
# -- Decompress file…
# -- Change encode to UTF-8
# ---- Transcoding…
# ---- Transcoding Done
# -- Transform to dataframe…
# -- Extract tourist rows
# -- START format dates and create new fields
# -- END format dates and create new fields
# 2020
# export_mensual_trf_202001.zip
# -- Decompress file…
# -- Change encode to UTF-8
# ---- Transcoding…
# ---- Transcoding Done
# -- Transform to dataframe…
# -- Extract tourist rows
# -- START format dates and create new fields
# -- END format dates and create new fields
# export_mensual_trf_202002.zip
# -- Decompress file…
# -- Change encode to UTF-8
# ---- Transcoding…
# ---- Transcoding Done
# -- Transform to dataframe…
# -- Extract tourist rows
# -- START format dates and create new fields
# -- END format dates and create new fields
# export_mensual_trf_202003.zip
# -- Decompress file…
# -- Change encode to UTF-8
# ---- Transcoding…
# ---- Transcoding Done
# -- Transform to dataframe…
# -- Extract tourist rows
# -- START format dates and create new fields
# -- END format dates and create new fields
# export_mensual_trf_202004.zip
# -- Decompress file…
# -- Change encode to UTF-8
# ---- Transcoding…
# ---- Transcoding Done
# -- Transform to dataframe…
# -- Extract tourist rows
# -- START format dates and create new fields
# -- END format dates and create new fields
# export_mensual_trf_202005.zip
# -- Decompress file…
# -- Change encode to UTF-8
# ---- Transcoding…
# ---- Transcoding Done
# -- Transform to dataframe…
# -- Extract tourist rows
# -- START format dates and create new fields
# -- END format dates and create new fields
# export_mensual_trf_202006.zip
# -- Decompress file…
# -- Change encode to UTF-8
# ---- Transcoding…
# ---- Transcoding Done
# -- Transform to dataframe…
# -- Extract tourist rows
# -- START format dates and create new fields
# -- END format dates and create new fields
# export_mensual_trf_202007.zip
# -- Decompress file…
# -- Change encode to UTF-8
# ---- Transcoding…
# ---- Transcoding Done
# -- Transform to dataframe…
# -- Extract tourist rows
# -- START format dates and create new fields
# -- END format dates and create new fields
# export_mensual_trf_202008.zip
# -- Decompress file…
# -- Change encode to UTF-8
# ---- Transcoding…
# ---- Transcoding Done
# -- Transform to dataframe…
# -- Extract tourist rows
# -- START format dates and create new fields
# -- END format dates and create new fields
# export_mensual_trf_202009.zip
# -- Decompress file…
# -- Change encode to UTF-8
# ---- Transcoding…
# ---- Transcoding Done
# -- Transform to dataframe…
# -- Extract tourist rows
# -- START format dates and create new fields
# -- END format dates and create new fields
# export_mensual_trf_202010.zip
# -- Decompress file…
# -- Change encode to UTF-8
# ---- Transcoding…
# ---- Transcoding Done
# -- Transform to dataframe…
# -- Extract tourist rows
# -- START format dates and create new fields
# -- END format dates and create new fields
# export_mensual_trf_202011.zip
# -- Decompress file…
# -- Change encode to UTF-8
# ---- Transcoding…
# ---- Transcoding Done
# -- Transform to dataframe…
# -- Extract tourist rows
# -- START format dates and create new fields
# -- END format dates and create new fields
# export_mensual_trf_202012.zip
# -- Decompress file…
# -- Change encode to UTF-8
# ---- Transcoding…
# ---- Transcoding Done
# -- Transform to dataframe…
# -- Extract tourist rows
# -- START format dates and create new fields
# -- END format dates and create new fields
# 2021
# export_mensual_trf_202101.zip
# -- Decompress file…
# -- Change encode to UTF-8
# ---- Transcoding…
# ---- Transcoding Done
# -- Transform to dataframe…
# -- Extract tourist rows
# -- START format dates and create new fields
# -- END format dates and create new fields
# export_mensual_trf_202102.zip
# -- Decompress file…
# -- Change encode to UTF-8
# ---- Transcoding…
# ---- Transcoding Done
# -- Transform to dataframe…
# -- Extract tourist rows
# -- START format dates and create new fields
# -- END format dates and create new fields
# export_mensual_trf_202103.zip
# -- Decompress file…
# -- Change encode to UTF-8
# ---- Transcoding…
# ---- Transcoding Done
# -- Transform to dataframe…
# -- Extract tourist rows
# -- START format dates and create new fields
# -- END format dates and create new fields
# export_mensual_trf_202104.zip
# -- Decompress file…
# -- Change encode to UTF-8
# ---- Transcoding…
# ---- Transcoding Done
# -- Transform to dataframe…
# -- Extract tourist rows
# -- START format dates and create new fields
# -- END format dates and create new fields
# export_mensual_trf_202105.zip
# -- Decompress file…
# -- Change encode to UTF-8
# ---- Transcoding…
# ---- Transcoding Done
# -- Transform to dataframe…
# -- Extract tourist rows
# -- START format dates and create new fields
# -- END format dates and create new fields
# export_mensual_trf_202106.zip
# -- Decompress file…
# -- Change encode to UTF-8
# ---- Transcoding…
# ---- Transcoding Done
# -- Transform to dataframe…
# -- Extract tourist rows
# -- START format dates and create new fields
# -- END format dates and create new fields
# export_mensual_trf_202107.zip
# -- Decompress file…
# -- Change encode to UTF-8
# ---- Transcoding…
# ---- Transcoding Done
# -- Transform to dataframe…
# -- Extract tourist rows
# -- START format dates and create new fields
# -- END format dates and create new fields
# export_mensual_trf_202108.zip
# -- Decompress file…
# -- Change encode to UTF-8
# ---- Transcoding…
# ---- Transcoding Done
# -- Transform to dataframe…
# -- Extract tourist rows
# -- START format dates and create new fields
# -- END format dates and create new fields
# export_mensual_trf_202109.zip
# -- Decompress file…
# -- Change encode to UTF-8
# ---- Transcoding…
# ---- Transcoding Done
# -- Transform to dataframe…
# -- Extract tourist rows
# -- START format dates and create new fields
# -- END format dates and create new fields
# export_mensual_trf_202110.zip
# -- Decompress file…
# -- Change encode to UTF-8
# ---- Transcoding…
# ---- Transcoding Done
# -- Transform to dataframe…
# -- Extract tourist rows
# -- START format dates and create new fields
# -- END format dates and create new fields
# export_mensual_trf_202111.zip
# -- Decompress file…
# -- Change encode to UTF-8
# ---- Transcoding…
# ---- Transcoding Done
# -- Transform to dataframe…
# -- Extract tourist rows
# -- START format dates and create new fields
# -- END format dates and create new fields
# export_mensual_trf_202112.zip
# -- Decompress file…
# -- Change encode to UTF-8
# ---- Transcoding…
# ---- Transcoding Done
# -- Transform to dataframe…
# -- Extract tourist rows
# -- START format dates and create new fields
# -- END format dates and create new fields
# 2022
# export_mensual_trf_202201.zip
# -- Decompress file…
# -- Change encode to UTF-8
# ---- Transcoding…
# ---- Transcoding Done
# -- Transform to dataframe…
# -- Extract tourist rows
# -- START format dates and create new fields
# -- END format dates and create new fields
# export_mensual_trf_202202.zip
# -- Decompress file…
# -- Change encode to UTF-8
# ---- Transcoding…
# ---- Transcoding Done
# -- Transform to dataframe…
# -- Extract tourist rows
# -- START format dates and create new fields
# -- END format dates and create new fields
# export_mensual_trf_202203.zip
# -- Decompress file…
# -- Change encode to UTF-8
# ---- Transcoding…
# ---- Transcoding Done
# -- Transform to dataframe…
# -- Extract tourist rows
# -- START format dates and create new fields
# -- END format dates and create new fields
